# %%
import Backetester as bt

# %%
testBB = bt.Backtester("USD_CAD", "BB", "2017-01-30", "2020-12-31", "D", SMA = 72, DEV = 2)
print(testBB.strategy_results("BB"))
testBB.plot_results()
print(testBB.optimize_parameters("BB", SMA_RANGE = (25, 100, 1), DEV_RANGE = (1, 5, 1)))
# Out:
#                               Open     High      Low    Close  Volume  \
# Date
# 2017-05-09 21:00:00+00:00  1.37232  1.37330  1.36473  1.36544   87532
# 2017-05-10 21:00:00+00:00  1.36544  1.37704  1.36531  1.36962   84448
# 2017-05-11 21:00:00+00:00  1.36952  1.37426  1.36656  1.37143   76049
# 2017-05-14 21:00:00+00:00  1.36962  1.37222  1.36018  1.36329   86504
# 2017-05-15 21:00:00+00:00  1.36312  1.36588  1.35747  1.36070   81287
# ...                            ...      ...      ...      ...     ...
# 2020-12-23 22:00:00+00:00  1.28502  1.28817  1.28133  1.28656   16121
# 2020-12-27 22:00:00+00:00  1.28570  1.28761  1.28137  1.28468   20748
# 2020-12-28 22:00:00+00:00  1.28540  1.28552  1.27802  1.28198   19918
# 2020-12-29 22:00:00+00:00  1.28194  1.28271  1.27496  1.27510   20895
# 2020-12-30 22:00:00+00:00  1.27556  1.27696  1.27141  1.27342   21158
#
#                             returns       SMA     Lower     Upper  distance  \
# Date
# ...

# %%
testEMA = bt.Backtester("USD_CAD", "EMA", "2017-01-30", "2020-12-31", "D", EMA_S = 50, EMA_L = 200)
testEMA.strategy_results("EMA")
testEMA.plot_results()

# %%
testMACD = bt.Backtester("USD_CAD", "MACD", "2017-01-30", "2020-12-31", "D", EMA_S = 50, EMA_L = 200, MACD_signal = 9)
testMACD.strategy_results("MACD")
testMACD.plot_results()
# Out:
#                               Open     High      Low    Close  Volume  \
# Date
# 2017-01-29 22:00:00+00:00  1.31370  1.31690  1.30766  1.31184   51072
# 2017-01-30 22:00:00+00:00  1.31194  1.31234  1.29689  1.30316   71314
# 2017-01-31 22:00:00+00:00  1.30304  1.31026  1.30294  1.30489   66472
# 2017-02-01 22:00:00+00:00  1.30476  1.30522  1.29803  1.30270   53134
# 2017-02-02 22:00:00+00:00  1.30284  1.30774  1.29924  1.30262   55529
# ...                            ...      ...      ...      ...     ...
# 2020-12-23 22:00:00+00:00  1.28502  1.28817  1.28133  1.28656   16121
# 2020-12-27 22:00:00+00:00  1.28570  1.28761  1.28137  1.28468   20748
# 2020-12-28 22:00:00+00:00  1.28540  1.28552  1.27802  1.28198   19918
# 2020-12-29 22:00:00+00:00  1.28194  1.28271  1.27496  1.27510   20895
# 2020-12-30 22:00:00+00:00  1.27556  1.27696  1.27141  1.27342   21158
#
#                             returns     EMA_S     EMA_L      MACD  MACD_Signal
# Date
# ...

# %%
testRSI = bt.Backtester("USD_CAD", "RSI", "2017-01-30", "2020-12-31", "D", RSI_periods = 14, RSI_upper = 70, RSI_lower = 30)
testRSI.strategy_results("RSI")
testRSI.plot_results()
# Out:
#                               Open     High      Low    Close  Volume  \
# Date
# 2017-01-29 22:00:00+00:00  1.31370  1.31690  1.30766  1.31184   51072
# 2017-01-30 22:00:00+00:00  1.31194  1.31234  1.29689  1.30316   71314
# 2017-01-31 22:00:00+00:00  1.30304  1.31026  1.30294  1.30489   66472
# 2017-02-01 22:00:00+00:00  1.30476  1.30522  1.29803  1.30270   53134
# 2017-02-02 22:00:00+00:00  1.30284  1.30774  1.29924  1.30262   55529
# ...                            ...      ...      ...      ...     ...
# 2020-12-23 22:00:00+00:00  1.28502  1.28817  1.28133  1.28656   16121
# 2020-12-27 22:00:00+00:00  1.28570  1.28761  1.28137  1.28468   20748
# 2020-12-28 22:00:00+00:00  1.28540  1.28552  1.27802  1.28198   19918
# 2020-12-29 22:00:00+00:00  1.28194  1.28271  1.27496  1.27510   20895
# 2020-12-30 22:00:00+00:00  1.27556  1.27696  1.27141  1.27342   21158
#
#                             returns        U        D      MA_U      MA_D  \
# Date
# ...

# %%
testSMA = bt.Backtester("USD_CAD", "SMA", "2017-01-30", "2020-12-31", "D", SMA_S = 50, SMA_L = 200)
testSMA.strategy_results("SMA")  
testSMA.plot_results()
# Out:
#                               Open     High      Low    Close  Volume  \
# Date
# 2017-01-29 22:00:00+00:00  1.31370  1.31690  1.30766  1.31184   51072
# 2017-01-30 22:00:00+00:00  1.31194  1.31234  1.29689  1.30316   71314
# 2017-01-31 22:00:00+00:00  1.30304  1.31026  1.30294  1.30489   66472
# 2017-02-01 22:00:00+00:00  1.30476  1.30522  1.29803  1.30270   53134
# 2017-02-02 22:00:00+00:00  1.30284  1.30774  1.29924  1.30262   55529
# ...                            ...      ...      ...      ...     ...
# 2020-12-23 22:00:00+00:00  1.28502  1.28817  1.28133  1.28656   16121
# 2020-12-27 22:00:00+00:00  1.28570  1.28761  1.28137  1.28468   20748
# 2020-12-28 22:00:00+00:00  1.28540  1.28552  1.27802  1.28198   19918
# 2020-12-29 22:00:00+00:00  1.28194  1.28271  1.27496  1.27510   20895
# 2020-12-30 22:00:00+00:00  1.27556  1.27696  1.27141  1.27342   21158
#
#                             returns     SMA_S     SMA_L
# Date
# 2017-01-29 22:00:00+00:00       NaN       NaN       NaN
# ...
